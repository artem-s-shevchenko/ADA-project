# %% [markdown]
# # Italian data

# %%
import os
import pandas as pd

# %%
with open("res_italy.json") as file:
    data = pd.read_json(file)
data.shape
# Out:
# (30254, 17)

# %%
data.head()
# Out:
#          asin    brand                  categories  \
# 0  B001E5E0D8  Lavazza  [[Grocery & Gourmet Food]]
# 1  B001E5E0D8  Lavazza  [[Grocery & Gourmet Food]]
# 2  B001E5E0D8  Lavazza  [[Grocery & Gourmet Food]]
# 3  B001E5E0D8  Lavazza  [[Grocery & Gourmet Food]]
# 4  B001E5E0D8  Lavazza  [[Grocery & Gourmet Food]]
#
#                                          description helpful  \
# 0  Lavazza Crema E Gusto Ground Coffee is an  Ara...  [0, 0]
# 1  Lavazza Crema E Gusto Ground Coffee is an  Ara...  [0, 0]
# 2  Lavazza Crema E Gusto Ground Coffee is an  Ara...  [0, 1]
# 3  Lavazza Crema E Gusto Ground Coffee is an  Ara...  [0, 0]
# 4  Lavazza Crema E Gusto Ground Coffee is an  Ara...  [1, 1]
#
#                                                imUrl  overall  price  \
# 0  http://ecx.images-amazon.com/images/I/51K6%2BX...        5  18.79
# 1  http://ecx.images-amazon.com/images/I/51K6%2BX...        5  18.79
# 2  http://ecx.images-amazon.com/images/I/51K6%2BX...        5  18.79
# 3  http://ecx.images-amazon.com/images/I/51K6%2BX...        5  18.79
# 4  http://ecx.images-amazon.com/images/I/51K6%2BX...        5  18.79
#
#                                              related  \
# 0  {'also_bought': ['B001E5E0DI', 'B003SRJ5Z8', '...
# 1  {'also_bought': ['B001E5E0DI', 'B003SRJ5Z8', '...
# 2  {'also_bought': ['B001E5E0DI', 'B003SRJ5Z8', '...
# 3  {'also_bought': ['B001E5E0DI', 'B003SRJ5Z8', '...
# 4  {'also_bought': ['B001E5E0DI', 'B003SRJ5Z8', '...
#
#                                           reviewText   reviewTime  \
# 0  One of the best coffee i have tasted. I bought...  09 21, 2013
# 1  I buy this coffee regularly from Amazon. It is...  04 18, 2010
# 2  I got hooked on Italian coffee in Rome nearly ...  08 19, 2013
# 3  Great price and a very nice coffee... this is ...   11 1, 2012
# 4  I purchased this brand of coffee when I purcha...  07 23, 2011
#
#        reviewerID             reviewerName                        salesRank  \
# 0  A103MNO3NK4PLT                       mo  {'Grocery & Gourmet Food': 126}
# 1  A2Y8RLJ0DSWGIC               NY shopper  {'Grocery & Gourmet Food': 126}
# 2  A106MNO7PYG1WL               Ace Sophia  {'Grocery & Gourmet Food': 126}
# 3  A2YBOE984WKQBP                    Vwong  {'Grocery & Gourmet Food': 126}
# 4  A10IKHRUSMKP46  J. Kaye Oldner "Judith"  {'Grocery & Gourmet Food': 126}
#
#                         summary  \
# 0  Best coffee for K-cup refill
# 1                  Great coffee
# 2            My Guilty Pleasure
# 3                    Love it...
# 4          New Espresso Drinker
#
#                                                title  unixReviewTime
# 0  Lavazza Crema e Gusto Ground Coffee, Italian ,...      1379721600
# 1  Lavazza Crema e Gusto Ground Coffee, Italian ,...      1271548800
# 2  Lavazza Crema e Gusto Ground Coffee, Italian ,...      1376870400
# 3  Lavazza Crema e Gusto Ground Coffee, Italian ,...      1351728000
# 4  Lavazza Crema e Gusto Ground Coffee, Italian ,...      1311379200

# %% [markdown]
# ## DATA CLEANING

# %%
# categories are like [[Health & Personal Care,...]], we are making them be "Health & Personal Care,..." 
def convert_cat():
    s = data["categories"]
    val = []
    for l in list(s): val.append("".join(l[0]))
    s_new = pd.Series(val, s.index.values)
    data["categories"]=s_new
convert_cat()

# %% [markdown]
# ### Join categories

# %%
data_new_categories = data.copy(deep=True)

# %%
fashion = ['Clothing, Shoes & JewelryNew Arrivals', 'Sports & OutdoorsAccessoriesSport Watches', 'Clothing', 
           'Shoes & JewelryLuxury Watches','Clothing, Shoes & JewelryLuggage & Travel GearLuggageSuitcases', 
           'Clothing, Shoes & JewelryLuggage & Travel GearLuggageGarment Bags',
      'Clothing, Shoes & JewelryJewelry: International Shipping Available', 
           'Clothing, Shoes & JewelryLuggage & Travel GearTravel AccessoriesPacking Organizers',
           'Clothing, Shoes & JewelryTTag Heuer', 'Clothing, Shoes & JewelryWomenWatchesWrist Watches', 
           'Clothing, Shoes & JewelryFashion Watches',
           'Clothing, Shoes & JewelryLuggage & Travel GearBackpacksCasual Daypacks', 
           'Clothing, Shoes & JewelryLuggage & Travel GearTravel AccessoriesTravel Wallets',
       'Clothing, Shoes & JewelryLuggage & Travel Gear', 'Clothing, Shoes & JewelryMenWatchesWrist Watches', 
           'Clothing, Shoes & JewelryWWenger','Clothing, Shoes & JewelryLuggage & Travel GearBriefcases', 
           'Clothing, Shoes & JewelryMenAccessoriesWallets, Card Cases & Money OrganizersCard & ID Cases',
       'Amazon Fashion', 'Clothing, Shoes & JewelryWomenWatchesWatch Bands', 
           'Arts, Crafts & SewingBeading & Jewelry-MakingJewelry-Making Tools & AccessoriesJewelry-Making Tools',
          'Clothing, Shoes & JewelryMenAccessoriesWallets, Card Cases & Money OrganizersMoney Clips', 
           'Office ProductsOffice & School SuppliesCarrying Cases',
           'Clothing, Shoes & JewelryLuggage & Travel GearLuggageTravel Duffels', 
           'Clothing, Shoes & JewelryLuggage & Travel GearLuggageTravel Totes',
           'Clothing, Shoes & JewelryLuggage & Travel GearLuggageCarry-Ons',   
           'Clothing, Shoes & JewelryWomenAccessoriesWallets, Card Cases & Money OrganizersWallets', 
           'Clothing, Shoes & JewelryGirls', 'Clothing, Shoes & JewelryWomen',
           'Clothing, Shoes & JewelryNovelty, Costumes & MoreBand & Music FanAccessories',
           'Video GamesPCAccessoriesHeadsets', 'Clothing, Shoes & JewelryShoes & Accessories: International Shipping Available',
           'Clothing, Shoes & JewelryOmega Watches', 'Clothing, Shoes & JewelryCollectible Watches',
           'Clothing, Shoes & JewelryLuggage & Travel GearFashion Waist Packs', 
           'Clothing, Shoes & JewelryLuggage & Travel GearTravel AccessoriesLuggage Locks',
           'Clothing, Shoes & JewelryBabyBaby GirlsClothingLayette Sets',
           'Office ProductsOffice & School SuppliesCarrying CasesPad Holders','Clothing, Shoes & JewelrySwatch Watches',
           'Clothing, Shoes & JewelryMenWatchesPocket Watches', 
           'Clothing, Shoes & JewelryLuggage & Travel GearTravel Accessories',
           'Office ProductsOffice & School SuppliesBinders & Binding SystemsBindersPadfolio Ring Binders',
           'Clothing, Shoes & JewelryLuggage & Travel GearMessenger Bags',
           'Clothing, Shoes & JewelryLuggage & Travel GearUmbrellas', 'Clothing, Shoes & JewelryMen',
           'Clothing, Shoes & JewelryLuggage & Travel GearTravel AccessoriesLuggage Straps',
           'Clothing, Shoes & JewelryGifts', 'Clothing, Shoes & JewelryLuxury Watches',
           'Office ProductsOffice & School SuppliesCalendars, Planners & Personal OrganizersPersonal Organizers',
            'Clothing, Shoes & JewelryMenWatchesWatch Bands'
          ] 
kitchen_tools = ['Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCarving Knives & ForksCarving Sets',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesBoning & Fillet Knives',
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsKnivesUtility Knives', 
                 'Sports & OutdoorsOutdoor GearCamping & HikingKnives & ToolsFolding Knives',
         "Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesChef's Knives", 
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsCooking UtensilsSpatulas',
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsMultitools & AccessoriesMultitools',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCarving Knives & ForksCarving Knives',
         'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesBread & Serrated KnivesSerrated Utility Knives', 
        'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesAsian KnivesSantoku Knives',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesBread & Serrated KnivesBread Knives',
        'Sports & OutdoorsHunting & FishingHuntingHunting & Tactical KnivesHunting KnivesFixed Blade Hunting Knives', 
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsCan Openers',
        'Home & KitchenKitchen & DiningKitchen Knives & Cutlery Accessories', 
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesParing Knives',
        'Home & KitchenKitchen & Dining', 
'Tools & Home ImprovementSafety & SecurityPersonal Protective EquipmentHand & Arm ProtectionLab', 
                 'Safety & Work GlovesCut Resistant Gloves', 
                'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutlery Sets',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesKnife Sharpeners',
                'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsSpecialty Tools & GadgetsSeafood Tools', 
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutlery SetsBoxed Knife Sets',
                'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesKnife Blocks & StorageKnife Blocks',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesUtility Knives',
               'Tools & Home ImprovementPower & Hand ToolsHand ToolsKnivesKnife Sets',
                 'Sports & OutdoorsHunting & FishingFishingFishing Tools & Maintenance EquipmentKnives',
                'Tools & Home ImprovementPower & Hand ToolsHand ToolsKnivesPocket Knives & Folding Knives', 
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsKnivesPocket Knives & Folding Knives',
                'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesKnife Blocks & StorageKnife Cases', 
                 'Holders & Protectors',
                'Tools & Home ImprovementPower & Hand ToolsHand ToolsKnives', 
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesSteak Knives',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutlery SetsKnife Block Sets',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsGraters, Peelers & SlicersMandolines & Slicers',
                 'Sports & OutdoorsOutdoor GearCamping & HikingKnives & ToolsFixed-Blade Knives',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsKitchen AccessoriesToothpick Holders',
                 'Tools & Home ImprovementHardwareCabinet HardwareLatches', 'Home & KitchenKitchen & DiningSmall Appliances',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsCheese ToolsSpreaders', 
                 'Home & KitchenKitchen & DiningStorage & Organization', 
                 'Home & KitchenStorage & OrganizationClothing & Closet StorageHangers', 
                 'Home & KitchenKitchen & DiningStorage & OrganizationLunch Boxes & BagsLunch Boxes',
                 'Home & KitchenKitchen & DiningSmall Appliance Parts & Accessories', 
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutlery SetsSteak Sets',
                 'Home & KitchenKitchen & DiningDining & EntertainingFlatwareKnives', 
                 'Office ProductsOffice & School SuppliesStaplers & PunchesManual StaplersDesktop Staplers',
                 'Home & KitchenKitchen & DiningWater Coolers & FiltersReplacement Water Filters',
                 'Tools & Home ImprovementHardwareDoor Hardware & LocksHandlesets', 
        'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesKnife Blocks & StorageMagnetic Knife Strips',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsGraters, Peelers & SlicersPeelers',
                 'Office ProductsOffice & School SuppliesForms, Recordkeeping & Money HandlingKey Tags & Chains',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesSpecialty KnivesGarnishing Knives',
                 'Sports & OutdoorsHunting & FishingHuntingHunting & Tactical KnivesHunting KnivesFolding Hunting Knives',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutlery Accessories',
                 'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesFood Processor Parts & Accessories',
                 'Sports & OutdoorsHunting & FishingHuntingHunting & Tactical KnivesHunting Knives',
                 'Home & KitchenKitchen & DiningDining & EntertainingCups, Mugs & SaucersCoffee Cups & Mugs',
                 'Tools & Home ImprovementHardwareNails, Screws & FastenersNails', 
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsWrenchesHex Keys',
                 'Office ProductsOffice & School SuppliesEducation & CraftsStudents Scissors',
                 'Tools & Home ImprovementPower & Hand ToolsHand Tools', 
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsFruit & Vegetable ToolsMelon Ballers',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesSpecialty KnivesTomato Knives',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsPasta & Pizza ToolsPizza Cutters',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsGraters, Peelers & Slicers',
                 'Tools & Home ImprovementRough PlumbingToilet PartsToilet Flush Valves',
        'Home & KitchenKitchen & DiningDining & EntertainingFlatwareServing UtensilsCake, Pie & Pastry Servers',
                 'Arts, Crafts & SewingCraft SuppliesWoodcrafts', 
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsMagnetic Sweepers',
                 'Tools & Home ImprovementPower & Hand ToolsHand ToolsMagnetic Sweepers',
                 'Office ProductsOffice & School SuppliesWriting & Correction SuppliesPens & RefillsPen Refills',
                 'Kitchen & Dining', 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesSpecialty Knives',
                 'Tools & Home ImprovementKitchen & Bath FixturesBathroom FixturesToilets & Toilet PartsToilet Tanks',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsMeasuring Tools & ScalesSpoons',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesShears',
                 'Tools & Home ImprovementBuilding SuppliesBuilding MaterialsRaw Building MaterialsMortar Mix',
                 'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesCutting Boards',
                 'Tools & Home ImprovementHardwareDoor Hardware & LocksLock Replacement Parts',
                 'Tools & Home ImprovementPower & Hand ToolsTool OrganizersTool Pouches',
                 'Tools & Home ImprovementSafety & SecurityPersonal Protective EquipmentHand & Arm ProtectionLab, Safety & Work GlovesSafety Work Gloves',
                 'Tools & Home ImprovementKitchen & Bath FixturesBathroom FixturesBathroom Sink & Bathtub AccessoriesSink & Bathtub DrainsSink Drains',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsCooking UtensilsLadles',
                 'Home & KitchenBeddingBed PillowsTravel Pillows', 
                 'Industrial & ScientificLab & Scientific ProductsLab Supplies & ConsumablesLab UtensilsLab Knives & Scalpels',
                 'Home & KitchenKitchen & DiningKitchen Utensils & GadgetsFruit & Vegetable ToolsZesters & Reamers',
                 'Sports & OutdoorsHunting & FishingFishingFishing Tools & Maintenance EquipmentPliers & Multi-Tools',
                 'Tools & Home ImprovementSafety & SecurityPersonal Protective EquipmentHand & Arm ProtectionLab, Safety & Work GlovesCut Resistant Gloves',
                 'Tools & Home ImprovementKitchen & Bath FixturesBathroom FixturesBathroom Hardware & InstallationBathroom Fixture Hardware Parts'
               
                ]
espresso_machines = ['Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machines', 
'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffee Filters',
                    'Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSemi-Automatic Espresso Machines',
                     'Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Makers',
                     'Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesMilk Frothers',
                     'Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSuper-Automatic Espresso Machines',
                     'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee & Espresso Machine Cleaning Products',
                     'Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machine & Coffeemaker Combos',
                     'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine AccessoriesMilk Frothing Pitchers',
                     'Home & KitchenKitchen & DiningCoffee, Tea & Espresso', 
                     'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine Accessories',
                     'Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersSingle-Serve Brewers',
                     'Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine AccessoriesTampers',
                     'Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersCoffee Machines',
                     'Home & KitchenKitchen & DiningKitchen Knives & Cutlery AccessoriesKnife Blocks & StorageKnife Cases, Holders & Protectors'
                    ]
pets=["Pet SuppliesDogsTreatsCookies, Biscuits & SnacksSnacks", 
      'Pet SuppliesDogsHealth SuppliesFlea, Lice & Tick ControlFlea Shampoos',
      'Pet SuppliesDogsHealth SuppliesFlea, Lice & Tick ControlFlea Drops',
      'Pet SuppliesCatsHealth SuppliesFlea, Lice & Tick ControlFlea Drops'
     ]
food = ['Grocery & Gourmet Food', 'Health & Personal CareSports Nutrition', 'Baby', 
        'Grocery & Gourmet FoodCandy & ChocolateBars', 'Office & School Supplies',
        'Grocery & Gourmet FoodCandy & ChocolateGummy Candy','Grocery & Gourmet FoodBeveragesTeaChai',
        'Health & Personal CareSports NutritionEndurance & EnergyCandy & Mints',
        'Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Capsules',
        'Grocery & Gourmet FoodCandy & ChocolateChocolate Truffles',
        'Grocery & Gourmet FoodBeveragesWaterSparkling & Mineral Water',
        'Grocery & Gourmet FoodBeveragesCoffeeCoffee Substitutes','Grocery & Gourmet FoodBaby FoodsCereal',
        'Grocery & Gourmet FoodBeveragesEnergy Drinks', 
        'Grocery & Gourmet FoodBeveragesPowdered Drink MixesInstant Breakfast Drinks',
        'Grocery & Gourmet FoodCandy & ChocolateHard Candy',
        'Grocery & Gourmet FoodBeveragesTeaHerbal',
        'Baby ProductsFeedingBottle-FeedingBottles','Grocery & Gourmet FoodBeveragesCoffeeInstant Coffee',
        'Grocery & Gourmet FoodBeveragesWater', 'Grocery & Gourmet FoodBeveragesHot Cocoa',
        'Grocery & Gourmet FoodBeveragesTeaTea Samplers'
       ]
electronic_and_games = ['ElectronicsComputers & AccessoriesCables & AccessoriesComputer Speakers',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesKeyboards',
             'ElectronicsComputers & AccessoriesCables & AccessoriesKeyboard & Mouse Combos',
                    'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesDocking Stations',
             'ElectronicsComputers & AccessoriesCables & AccessoriesMice', 
                    'ElectronicsComputers & AccessoriesTouch Screen Tablet AccessoriesCases & SleevesCases',
             'Health & Personal CareHousehold SuppliesHousehold BatteriesCoin & Button Cell', 
                    'Video GamesPCAccessoriesGaming Mice',
            'Cell Phones & AccessoriesCasesBasic Cases', 'ElectronicsComputers & AccessoriesWebcams', 
                    'BeautySkin CareFaceCreams & MoisturizersFluids & LotionsLotions',
             'ElectronicsComputers & AccessoriesCables & AccessoriesHeadsets & MicrophonesPC Headsets', 
                    'Cell Phones & AccessoriesAccessoriesHeadsetsBluetooth Headsets',
             'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesBags & CasesBackpacks',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesHeadsets & Microphones',
             'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesBags & CasesSleeves & Slipcases',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesInput DevicesTouch Pads',
             'ElectronicsAccessories & SuppliesAudio & Video AccessoriesHeadphones', 
                    'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesBags & CasesMessenger Bags',
             'ElectronicsComputers & AccessoriesTouch Screen Tablet AccessoriesSkins & Decals', 
                    'Video GamesPCAccessories',
                    'ElectronicsPortable Audio & VideoMP3 Players & AccessoriesMP3 Player AccessoriesSpeaker Systems',
              'Toys & GamesGamesGame Collections', 'ElectronicsHome AudioRadiosInternet Radios', 
        'Office ProductsOffice & School SuppliesDesk Accessories & Workspace OrganizersMouse Pads & Wrist RestsMouse Pads',
              'Computers', 'ElectronicsGPS & NavigationGPS System AccessoriesCases', 'Toys & GamesBuilding ToysBuilding Sets', 
                    'Toys & GamesBuilding Toys',
               'ElectronicsComputers & AccessoriesCables & AccessoriesCables & InterconnectsUSB Cables',    
                    'Video GamesPCAccessoriesGaming Keyboards',
              'ElectronicsHome AudioStereo ComponentsSpeakersSpeaker Systems',       
            'ElectronicsCamera & PhotoVideo SurveillanceSurveillance CamerasSimulated Cameras',
            'Video GamesMore SystemsGameCubeHardwareAccessories',
            'ElectronicsAccessories & SuppliesAudio & Video AccessoriesCables & InterconnectsPower Cables',
                    'ElectronicsHome AudioStereo ComponentsSpeakers', 
                    'ElectronicsAccessories & SuppliesAudio & Video AccessoriesRemote ControlsTV Remote Controls',
             'ElectronicsComputers & AccessoriesCables & Accessories', 'Video GamesPCAccessoriesControllersJoysticks',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesInput DevicesTrackballs',
                    'ElectronicsAccessories & SuppliesAudio & Video AccessoriesConnectors & Adapters',
                'Cell Phones & AccessoriesAccessoriesBluetooth Speakers', 
                    'ElectronicsComputers & AccessoriesCables & AccessoriesCleaning & RepairRepair Kits',
                'Toys & GamesLearning & EducationScience', 'Video GamesPCAccessoriesHeadsets',
                    'ElectronicsPortable Audio & VideoMP3 Players & AccessoriesMP3 Player AccessoriesCases',
                'ElectronicsComputers & AccessoriesComputer ComponentsMemory', 
                    'Home & KitchenBathBathroom AccessoriesBathroom Accessory Sets', 'ElectronicsComputers & Accessories',
                'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesChargers & Adapters',
                    'ElectronicsComputers & AccessoriesComputer Components',
                    'ElectronicsAccessories & SuppliesAudio & Video AccessoriesRemote ControlsRemote-Control Extenders',
                   'Toys & GamesToy Remote Control & Play VehiclesVehicle Playsets',  
            'ElectronicsTelevision & VideoStreaming Media Players', 'Toys & GamesToy Remote Control & Play VehiclesPlay Vehicles',
                    'ElectronicsPortable Audio & VideoMP3 Players & AccessoriesMP3 Player AccessoriesRemote Controls',
                    'ElectronicsAccessories & SuppliesBatteries, Chargers & AccessoriesAC Adapters',
              'Video GamesPCAccessoriesControllersGamepads',  'ElectronicsHome AudioStereo ComponentsTurntables',
                    'Toys & GamesNovelty & Gag ToysLight-Up Toys', 'All Electronics', 
            'ElectronicsAccessories & SuppliesAudio & Video Accessories', 
                    'ElectronicsAccessories & SuppliesBatteries, Chargers & AccessoriesPower Converters',
                    'ElectronicsComputers & AccessoriesRouters',
                    'ElectronicsComputers & AccessoriesTouch Screen Tablet AccessoriesCases & Sleeves',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesVideo Projector AccessoriesLamps',
                 'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesBatteries',
                    'Office ProductsOffice ElectronicsTelephones & AccessoriesAudio Conferencing',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesHeadsets & MicrophonesPC Microphones',
                    'ElectronicsComputers & AccessoriesCables & AccessoriesInput DevicesNumeric Keypads',
                    'ElectronicsComputers & AccessoriesTouch Screen Tablet Accessories',
                    'ElectronicsComputers & AccessoriesTouch Screen Tablet AccessoriesStands',
                    'ElectronicsCamera & PhotoVideo SurveillanceSurveillance CamerasHidden Cameras',
                    'Cell Phones & AccessoriesAccessoriesHeadsetsWired Headsets',
                'ElectronicsCamera & PhotoBags & CasesCamera Cases',  
                    'Office ProductsOffice ElectronicsPresentation ProductsPresentation PointersPresentation Remotes',
                    'Toys & Games', 'Video GamesMore SystemsPlayStation 2HardwareAccessories',
                    'Cell Phones & AccessoriesAccessoriesChargersTravel Chargers', 
                    'ElectronicsAccessories & SuppliesAudio & Video AccessoriesHeadphone Accessories',
                    'ElectronicsComputers & AccessoriesPDAs, Handhelds & AccessoriesPDA & Handheld AccessoriesKeyboards & Styluses',
                    'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesCooling Pads',
                    'ElectronicsAccessories & SuppliesTelephone AccessoriesBatteries',
                    'ElectronicsAccessories & SuppliesBatteries, Chargers & AccessoriesPDUs', 
                    'Toys & GamesSports & Outdoor PlaySportsBasketball',
                    'ElectronicsComputers & AccessoriesPDAs, Handhelds & AccessoriesPDA & Handheld AccessoriesCases',
                    'Toys & GamesAction Figures & StatuesAction Figures',
                    'ElectronicsComputers & AccessoriesLaptop & Netbook Computer AccessoriesBags & Cases',
                        'Toys & GamesBaby & Toddler ToysActivity Play Centers'
             ]
sports = ['Sports & OutdoorsExercise & FitnessStrength Training EquipmentDumbbells', 
          'Sports & OutdoorsExercise & FitnessAccessories',
         'Sports & OutdoorsAccessories', 'Sports & OutdoorsCyclingBike Tools & MaintenanceGrease', 
          'Sports & OutdoorsAccessoriesSports Water Bottles'
         'Sports & OutdoorsAccessoriesSports Sunglasses', 'Sports & OutdoorsOutdoor GearCamping & Hiking', 
         'Sports & OutdoorsCyclingHydrationWater Bottles', 
          'Sports & OutdoorsOutdoor GearCamping & HikingBackpacks & BagsHiking Daypacks', 
          'Sports & OutdoorsOutdoor GearCamping & HikingPersonal CareInsect Repellent',
          'Sports & OutdoorsTeam SportsCurlingBrooms & Brushes', 'Sports & OutdoorsBoating & Water SportsSwimmingGoggles',
          'Sports & OutdoorsExercise & FitnessAccessoriesExercise Balls & Accessories',
          'Sports & OutdoorsCyclingBike Tools & MaintenanceCleaners', 
          'Sports & OutdoorsOutdoor GearCamping & HikingCamp BeddingBlankets',
          'Sports & OutdoorsCyclingBike Tools & MaintenanceBike Lube', 
          'Sports & OutdoorsAccessoriesSports Water Bottle Accessories',
          'Sports & OutdoorsExercise & FitnessStrength Training EquipmentBack Machines','Sports & Outdoors',
          'Sports & OutdoorsExercise & FitnessAccessoriesGloves', 'Sports & OutdoorsAction SportsSkateboardingHelmets',
          'Sports & OutdoorsHunting & FishingTactical & DutyTactical Bags & Packs',
          'Sports & OutdoorsFan ShopSports SouvenirsTrading Cards',
          'Sports & OutdoorsOutdoor GearCamping & HikingHydration',
          'Sports & OutdoorsAccessoriesSports Water Bottles',
          'Sports & OutdoorsAccessoriesSports Sunglasses'
         ]
personal_care= ['Health & Personal CarePersonal CareDeodorants & AntiperspirantsDeodorants', 
                'BeautySkin CareFaceCreams & Moisturizers',
          'Health & Personal CareHealth CareMassage & RelaxationAromatherapyOils', 'BeautyBath & BodyCleansersBody Washes',
          'BeautySkin CareFaceCreams & MoisturizersFluids & LotionsLotions', "BeautyFragranceWomen'sEau de Parfum", 
                'BeautySkin CareBodyMoisturizersLotions', 
           "Health & Personal CareHealth CareSmoking CessationNicotine Gums & Lozenges", 
                'Health & Personal CareHealth CareCough & ColdCoughing & Sore ThroatsCough Drops',
            'Health & Personal CareHousehold Supplies', 'Health & Personal CareMedical Supplies & Equipment',
                'Health & Personal CareHealth CareMassage & RelaxationMassage Oils',
            'Health & Personal CarePersonal CareEye CareEye Drops, Lubricants & Washes', 
                'BeautySkin CareHands & NailsHand Creams & Lotions',
        'Health & Personal Care', 'BeautyTools & AccessoriesBags & CasesCosmetic Bags', 
                'Health & Personal CareMedical Supplies & EquipmentDaily Living Aids',
               'BeautyMakeupMakeup RemoverEyes', 'BeautySkin CareFaceCreams & MoisturizersNight Creams', 
                'BeautyBath & BodyCleansersSoaps',
               'Baby ProductsBathing & Skin CareSkin CareDiaper Creams', 'BeautySkin CareBodyMoisturizersOils', 
               'Health & Personal CareHealth CareDigestion & NauseaAntacids', 
                'BeautySkin CareFaceCreams & MoisturizersDay Creams', 
                'Industrial & ScientificProfessional Dental SuppliesOral Hygiene & Preventive CareToothpastes',
                'Arts, Crafts & SewingCraft SuppliesPaper & Paper CraftsPapermaking', 
                'BeautyHair CareStyling ProductsHair Styling Serums', 'BeautySkin CareBodyMoisturizersCreams', 
                'BeautySkin CareFaceTreatments & Masks','Baby ProductsBathing & Skin CareSkin CareLotions',
                'Health & Personal CareVitamins & Dietary SupplementsSupplements', 'BeautySkin CareMaternity',
                'Health & Personal CarePersonal CareShaving & Hair RemovalShaving Creams, Lotions & SoapsCreams', 
                'Health & Personal CareVitamins & Dietary SupplementsHerbal Supplements', 
                'Health & Personal CareMedical Supplies & EquipmentHome Tests', 'BeautySkin CareEyesDark Circle Treatments',
                'BeautyTools & AccessoriesBags & CasesToiletry Bags',
                'Health & Personal CarePersonal CareLip CareBalms & Moisturizers', 'BeautyHair CareHair & Scalp Treatments',
                'BeautyBath & BodyScrubs & Body TreatmentsBody Mud', 
                'Health & Personal CareHealth CareFirst Aid','BeautyTools & AccessoriesNail ToolsClippers & Trimmers',
                'Health & Personal CarePersonal CareEye CareContact Lens CareRewetting Drops','BeautyBath & BodyBathOils',
                'Health & Personal CarePersonal Care', "BeautyFragranceWomen'sEau de Toilette",
                'Health & Personal CarePersonal CareEye CareContact Lens CareSoaking Solutions',
                'Health & Personal CareMedical Supplies & EquipmentDiabetes Care', 'BeautyHair CareShampoos',
                'BeautySkin CareEyesCreams', 
                'Health & Personal CareMedical Supplies & EquipmentDaily Living AidsEating & Drinking Aids',
                'Health & Personal CareSports NutritionProteinPowdersWhey',
                'Health & Personal CareHealth CareCough & ColdCold & Flu Relief','BeautyMakeupLipsLip Glosses',
                'BeautySkin CareFaceTreatments & MasksMasks',
                'Health & Personal CarePersonal CareOral HygieneBreath FreshenersBreath Mints','Baby ProductsBathing & Skin Care',
                'Health & Personal CareVitamins & Dietary SupplementsSupplementsAntioxidantsLutein',
                'Health & Personal CareVitamins & Dietary SupplementsSupplementsDigestive SupplementsProbiotics','All Beauty',
                'Health & Personal CareHealth CarePain RelieversRubs & Ointments', 
                'Health & Personal CareHealth CareDigestion & NauseaLaxatives', 'Health & Personal CarePersonal CareEye Care',
                'BeautySkin CareFaceToners & Astringents', 'Health & Personal CareHealth CareFirst AidBurn Care',
                'BeautyHair CareConditioners', 
                'Health & Personal CareVitamins & Dietary SupplementsSupplementsDigestive SupplementsDietary Fibers',
                'Health & Personal CareHealth CareTherapeutic Skin Care',
                'Industrial & ScientificProfessional Medical SuppliesFluid Administration & CollectionBlood Lancets',
                'Health & Personal CarePersonal CareShaving & Hair RemovalHair RemovalTweezers',
                'Health & Personal CarePersonal CareEye CareContact Lens CareCleaners',
                'BeautyBath & BodyScrubs & Body TreatmentsBody Scrubs', 'BeautySkin CareFaceOils & Serums',
                'Health & Personal CarePersonal CareShaving & Hair RemovalAfter Shaves & Grooming AidsLotions & Tonics',
                'Health & Personal CarePersonal CareShaving & Hair RemovalAfter Shaves & Grooming Aids',
                'Health & Personal CarePersonal CareEye CareContact Lens Care',
                'Health & Personal CarePersonal CareFoot CareFoot Creams & Lotions', 
                'Health & Personal CareHealth CareDigestion & NauseaGas Relief', "BeautyFragranceMen'sEau de Toilette",
                "Industrial & Scientific", 'Health & Personal CareBaby & Child CarePersonal CareBaby Bath',
                'Industrial & ScientificProfessional Medical SuppliesFluid Administration & Collection',
                'Baby ProductsBathing & Skin CareGrooming & Healthcare Kits', 
                'Baby ProductsBathing & Skin CareSoaps & CleansersBody Wash','Baby ProductsBathing & Skin CareSkin CareOils',
                'Health & Personal CareMedical Supplies & EquipmentDiabetes CareLancets', 
                'Health & Personal CareMedical Supplies & EquipmentDiabetes CareTest StripsBlood Test Strips',
                'BeautySkin CareFaceExfoliators & ScrubsScrubs', 'Baby ProductsBathing & Skin CareSoaps & CleansersBar Soaps'
               ]
motors = ['AutomotiveOils & FluidsOilsMotor Oils', 'AutomotiveMotorcycle & PowersportsParts', 
          'AutomotiveMotorcycle & PowersportsPartsDrive TrainChains & SprocketsChains', 
          'AutomotiveMotorcycle & PowersportsPartsFiltersAir Filters',
          'Industrial & ScientificTapes, Adhesives & SealantsIndustrial SealantsThread Sealants',
          'AutomotiveCar CareExterior CareCleaners', 'AutomotiveMotorcycle & PowersportsProtective GearHelmets',
          'AutomotiveInterior AccessoriesKey Chains', 'AutomotiveOils & FluidsOilsHydraulic Oils',
          'AutomotiveReplacement PartsStarters & AlternatorsAlternators & GeneratorsVoltage Regulators',
          'Industrial & ScientificTapes, Adhesives & SealantsSilicone Adhesives',
          'Industrial & ScientificTapes, Adhesives & SealantsIndustrial Sealants',
          'AutomotiveOils & FluidsBody Repair & Restoration ChemicalsAdhesives'
         ]
gardening = ['Patio, Lawn & GardenGardening & Lawn CareSoils, Fertilizers & MulchesFertilizers & Plant Food', 
             'Patio, Lawn & GardenPest ControlLures',
             'Office ProductsOffice & School SuppliesPaperCopy & Multipurpose Paper',
             'Patio, Lawn & GardenGardening & Lawn CareWeed & Moss ControlWeed Killers'
             ]

# %%
for index, row in data_new_categories.iterrows():
    if row["categories"] in fashion: data_new_categories.set_value(index, 'categories', "fashion")
    if row["categories"] in kitchen_tools: data_new_categories.set_value(index, 'categories', "kitchen_tools")
    if row["categories"] in espresso_machines: data_new_categories.set_value(index, 'categories', "espresso_machines")
    if row["categories"] in pets: data_new_categories.set_value(index, 'categories', "pets")
    if row["categories"] in food: data_new_categories.set_value(index, 'categories', "food")
    if row["categories"] in electronic_and_games: data_new_categories.set_value(index, 'categories', "electronic_and_games")
    if row["categories"] in sports: data_new_categories.set_value(index, 'categories', "sports")
    if row["categories"] in personal_care: data_new_categories.set_value(index, 'categories', "personal_care")
    if row["categories"] in motors: data_new_categories.set_value(index, 'categories', "motors")
    if row["categories"] in gardening: data_new_categories.set_value(index, 'categories', "gardening")
data_new_categories = data_new_categories[
                                         (data_new_categories["categories"]=="fashion") |
                                         (data_new_categories["categories"]=="kitchen_tools") |
                                         (data_new_categories["categories"]=="espresso machines") |
                                         (data_new_categories["categories"]=="pets") |
                                         (data_new_categories["categories"]=="food") |
                                         (data_new_categories["categories"]=="electronic_and_games") |
                                         (data_new_categories["categories"]=="sports") |
                                         (data_new_categories["categories"]=="personal_care") |
                                         (data_new_categories["categories"]=="motors") |
                                         (data_new_categories["categories"]=="gardening")
                                         ]

# %%
data_new_categories["categories"].drop_duplicates()
# Out:
# 0                        food
# 564                   fashion
# 4729     electronic_and_games
# 5382            kitchen_tools
# 20051           personal_care
# Name: categories, dtype: object

# %% [markdown]
# ## CATEGORY STATS - numeric ratings

# %%
#Mean rating of each brand
#make weighted statistic of data - take overall rate according to helpfulness (how helpful is rating and comment)
def calculate_review(data_frame):
    s=[]
    overall=[]
    overall_count=0
    for index, row in data_frame.iterrows():
        if row["helpful"][1]!=0: #and row["helpful"][1]>=3:
            overall.append(row["overall"]*(row["helpful"][0]/row["helpful"][1]))
            overall_count+=row["helpful"][0]/row["helpful"][1]
        #else: 
            #overall.append(row["overall"])
            #overall_count+=1
    if overall_count!=0: return sum(overall)/overall_count
    else: return 0

# %%
#mean ratings for each category
def mean_ratings(data):
    category_group = data.groupby("categories")
    s=[]
    for c in list(category_group.groups):
        group_cat = pd.DataFrame(category_group.get_group(c))
        s.append(str(c)+", number of votes: "+str(len(group_cat))+ ", mean: "+ str(calculate_review(group_cat)))
    for i in range (5): print (s[i])
mean_ratings(data)
# Out:
# Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Makers, number of votes: 99, mean: 3.7874203296357805
# Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersCoffee Machines, number of votes: 2649, mean: 3.317980741142911
# Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffeemaker Pot Lids, number of votes: 12, mean: 4.851851851851852
# Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSemi-Automatic Espresso Machines, number of votes: 1573, mean: 3.6289261274835107
# Home & KitchenKitchen & DiningCookwareCookware Sets, number of votes: 2, mean: 0

# %%
#what are the most and the least popular products within each category
import operator
def popular_products(data):
    categories = data["categories"].drop_duplicates()
    grouped_cat = data.groupby("categories")
    for cat in categories:
        category = pd.DataFrame(grouped_cat.get_group(cat))
        products = category["asin"].drop_duplicates()
        grouped_products = category.groupby("asin")
        reviews={}
        for p in products:
            product = pd.DataFrame(grouped_products.get_group(p))
            if calculate_review(product)!=0: reviews[list(product["title"])[0]]=calculate_review(product)
        sorted_reviews = sorted(reviews.items(), key=operator.itemgetter(1), reverse=True)
        print ("CATEGORY: ",cat, ", BEST REVIEWS: ", sorted_reviews[0:3], "\nCATEGORY: ",cat, ", WORST REVIEWS: ", sorted_reviews[-4:-1], "\n")
popular_products(data)
# Out:
# CATEGORY:  Grocery & Gourmet Food , BEST REVIEWS:  [('Ferrero Yogurette 24 pieces', 5.0), ('Parmalat 2% Reduced Fat Milk 1 Qt (Pack of 6)', 5.0), ('Lavazza Italian &quot;Qualita Rossa&quot; Ground Espresso (1 case = 20 x 8.8 oz bricks)', 5.0)]
# CATEGORY:  Grocery & Gourmet Food , WORST REVIEWS:  [('Nutella Hazelnut Spread 200g : Glass Jar - European Import - THE Real Nutella! Bonus Nutella Cake Recipe', 1.5882352941176472), ('Lavazza Crema &amp; Aroma Espresso Point Machine Cartridges, 50/pack model # 460', 1.0), ('Lavazza Espresso Delicato for Keurig Rivo System', 1.0)]
#
# CATEGORY:  Clothing, Shoes & JewelryLuxury Watches , BEST REVIEWS:  [("Panerai Luminor 1950 10 Days Men's Automatic - PAM00270", 5.0)]
# CATEGORY:  Clothing, Shoes & JewelryLuxury Watches , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & PartsRadio Receivers , BEST REVIEWS:  [('Tactic TR624 2.4Ghz 6CH Receiver', 5.0)]
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & PartsRadio Receivers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingGlassware & DrinkwareWine Glasses , BEST REVIEWS:  [('Lavazza Crema &amp; Aroma Espresso Point Machine Cartridges, 100/pack model # 460', 4.529411764705882)]
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingGlassware & DrinkwareWine Glasses , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesTricycles, Scooters & WagonsRide-On Toys , BEST REVIEWS:  [('John Deere Gator Motor Gearbox by Peg Perego', 5.0), ('Peg Perego Case IH Tractor and Trailer', 5.0), ("Chicco Sit 'N Ride Train", 4.869565217391305)]
# CATEGORY:  Toys & GamesTricycles, Scooters & WagonsRide-On Toys , WORST REVIEWS:  [('Peg Perego 12 Volt Battery Charger', 2.9894055326662747), ('Peg Perego Battery 12 Volt (Drop Ship Pack)', 2.7808818003256626), ('Peg Perego 24 Volt Replacement Battery for Peg Perego Vehicles', 2.4615384615384617)]
#
# CATEGORY:  Toys & GamesElectronics for KidsElectronic Toys , BEST REVIEWS:  [('Chicco Toys Talking Vacation Car', 5.0), ('Chicco Talking Farm', 5.0), ('Chicco Talking Key', 5.0)]
# CATEGORY:  Toys & GamesElectronics for KidsElectronic Toys , WORST REVIEWS:  [('Chicco Talking DJ', 4.076923076923077), ('Chicco Tot Smart Laptop', 4.0), ('Chicco Toys Sing Along Airplane', 3.0)]
#
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Pods , BEST REVIEWS:  [('Lavazza 2410 Gran Filtro Italian Light Roast Coffee, Arabica Blend, Whole Bean, 2 1/5 Bag', 5.0), ('LAVAZZA POINT - CREMA &amp; AROMA GRAND ESPRESSO 100 CARTRIDGES', 5.0)]
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Pods , WORST REVIEWS:  [('Lavazza 2410 Gran Filtro Italian Light Roast Coffee, Arabica Blend, Whole Bean, 2 1/5 Bag', 5.0)]
#
# CATEGORY:  Office ProductsOffice & School SuppliesFiling ProductsFoldersFile FoldersColored , BEST REVIEWS:  [('Lion Steel SR1-ARB Folder', 4.0)]
# CATEGORY:  Office ProductsOffice & School SuppliesFiling ProductsFoldersFile FoldersColored , WORST REVIEWS:  []
#
# CATEGORY:  Baby , BEST REVIEWS:  [('Peg Perego Siesta High Chair with Splat Matt - Noce', 5.0), ('Peg Perego Primo Viaggio SIP Convertible Car Seat in Crystal Red', 5.0), ('Chicco Liteway Plus Stroller, Surge', 5.0)]
# CATEGORY:  Baby , WORST REVIEWS:  [('Peg Perego Pliko Mini Boot, Charcoal', 1.8000000000000003), ('Peg Perego Booster Cushion, White', 1.0), ('Chicco NextFit Convertible Car Seat - Infiniti', 1.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersCoffee Machines , BEST REVIEWS:  [('DeLonghi Descaling Solution Fluid 16.9oz', 4.301913205786282), ('DeLonghi Kmix 5-Cup Drip Coffee Maker, Green', 3.407991088504422), ('DeLonghi Kmix 10-Cup Drip Coffee Maker, Magenta', 3.4079910885044216)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersCoffee Machines , WORST REVIEWS:  [('DeLonghi DCF2210TTC 10-Cup Thermal Carafe Drip Coffee Maker, Black', 2.9376261599887976), ('DeLonghi DCF2212T 12-Cup Glass Carafe Drip Coffee Maker, Black', 2.8265598152675993), ('DeLonghi DC514T 14-Cup Programmable Drip Coffeemaker', 2.7161739737303967)]
#
# CATEGORY:  Toys & GamesBaby & Toddler ToysPush & Pull Toys , BEST REVIEWS:  [('Chicco Talking Dragon', 4.666666666666667), ('Chicco Baby Activity Walker - Pink', 4.0), ('Chicco 4-in-1 Ride-On Car, Orange', 3.555555555555556)]
# CATEGORY:  Toys & GamesBaby & Toddler ToysPush & Pull Toys , WORST REVIEWS:  [('Chicco Talking Dragon', 4.666666666666667), ('Chicco Baby Activity Walker - Pink', 4.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machines , BEST REVIEWS:  [('Gaggia Synchrony Logic RS', 5.0), ('Gaggia Platium Vision 90950 Automatic Espresso Machine with Free Milk Island, Champagne', 5.0), ("De'Longhi EC220b 15-Bar Pump Driven Espresso Maker", 4.454545454545454)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machines , WORST REVIEWS:  [('Gaggia 12101 New Baby Manual Espresso Machine, Black', 3.6424876031578384), ('Gaggia 102534 Espresso-Color Semi-Automatic Espresso Machine, Red', 3.405990163701023), ('DeLonghi EC702 15-Bar-Pump Espresso Maker, Stainless', 3.3903244503532486)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSemi-Automatic Espresso Machines , BEST REVIEWS:  [("De'Longhi ECO310W Espresso Maker", 5.0), ('Gaggia Classic Espresso Machine - Brushed Steel|14101', 4.2105263157894735), ('Gaggia 14101 Classic Espresso Machine, Brushed Stainless Steel', 4.039177407814278)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSemi-Automatic Espresso Machines , WORST REVIEWS:  [('DeLonghi Kmix 15 Bars Pump Espresso Maker, White', 3.248200982279807), ('DeLonghi Kmix 15 Bars Pump Espresso Maker, Yellow', 3.248200982279807), ('DeLonghi Kmix 15 Bars Pump Espresso Maker, Red', 3.248200982279807)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSuper-Automatic Espresso Machines , BEST REVIEWS:  [('Gaggia Titanium Office (90650) Espresso Machine', 5.0), ('Philips Saeco HD8856/47 Exprelia Automatic Espresso Machine, Stainless Steel', 4.54375667022412), ('Rancilio HSD-SILVIA Silvia Espresso Machine', 4.463286845969231)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSuper-Automatic Espresso Machines , WORST REVIEWS:  [('Gaggia 90800 Platinum Vogue Automatic Espresso Machine, Silver', 3.146551724137931), ('DeLonghi ESAM5500M Perfecta Digital Super-Automatic Espresso Machine, Metallic Blue', 3.110456661220182), ('Gaggia 90901 Platinum Swing Up Automatic Espresso Machine with Milk Island', 3.0185185185185186)]
#
# CATEGORY:  Toys & GamesBaby & Toddler ToysMusic & Sound , BEST REVIEWS:  [('Go Go Buddies Jazz-a-snail', 5.0), ('Chicco Baby Driver', 4.706806282722513), ('Chicco 3-in-1 Music Band Table', 2.8181818181818183)]
# CATEGORY:  Toys & GamesBaby & Toddler ToysMusic & Sound , WORST REVIEWS:  [('Go Go Buddies Jazz-a-snail', 5.0), ('Chicco Baby Driver', 4.706806282722513)]
#
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir Conditioners & AccessoriesPortable , BEST REVIEWS:  [('DeLonghi PACC100E 10,000 BTU Portable Air Conditioner with Remote Control', 5.0), ('DeLonghi PACN100E Portable Air Conditioner', 4.114596078347926), ('Delonghi Pac N115ec Portable Air Conditioner', 4.0)]
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir Conditioners & AccessoriesPortable , WORST REVIEWS:  [('DeLonghi PACC120E 12,000 BTU Portable Air Conditioner with Remote Control', 3.7935483140273822), ('DeLonghi PACN110EC Portable Air Conditioner', 3.6798365122615806), ('DeLonghi PACN120E Portable Air Conditioner', 3.001446333909918)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee & Espresso Machine Cleaning Products , BEST REVIEWS:  [('Rancilio Silvia Espresso Machine Repair Kit', 4.75), ('Gaggia Decalcifier Descaler Solution,250ml', 4.366666666666666), ("De'Longhi ECODECALK EcoDeCalk Natural Descaler for Coffee Machines", 4.173913043478261)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee & Espresso Machine Cleaning Products , WORST REVIEWS:  [('Gaggia Decalcifier Descaler Solution,250ml', 4.366666666666666), ("De'Longhi ECODECALK EcoDeCalk Natural Descaler for Coffee Machines", 4.173913043478261), ('Saeco CA6706/48 Espresso Machine Maintenance Kit', 3.972762645914397)]
#
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Cups , BEST REVIEWS:  [('LAVAZZA ESPRESSO DELICATO 72 PACKS made for KEURIG RIVO SYSTEM', 5.0), ('LAVAZZA ESPRESSO INTENSO 72 PACKS made for KEURIG RIVO SYSTEM', 4.75), ('LAVAZZA ESPRESSO CLASSICO 90 PACKS made for KEURIG RIVO SYSTEM', 4.5)]
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Cups , WORST REVIEWS:  [('LAVAZZA ESPRESSO DELICATO 72 PACKS made for KEURIG RIVO SYSTEM', 5.0), ('LAVAZZA ESPRESSO INTENSO 72 PACKS made for KEURIG RIVO SYSTEM', 4.75)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersToaster Ovens , BEST REVIEWS:  [('0.5 Cu. Ft. Digital Convection Toaster Oven', 4.051823390907888), ('DeLonghi EOP2046 Toaster Oven with Integrated Panini Press', 3.723120331950208), ("De'Longhi EO-2058 6 Slice Toaster/Convection Oven", 3.559119403982275)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersToaster Ovens , WORST REVIEWS:  [("De'Longhi EO-2058 6 Slice Toaster/Convection Oven", 3.559119403982275), ('DeLonghi Digital Convection Toaster Oven', 2.843815665909231), ('DeLonghi RO2058 6-Slice Convection Toaster Oven with Rotisserie', 2.816276191162648)]
#
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeGround Coffee , BEST REVIEWS:  [('Lavazza Crema e Gusto Ground Coffee, Italian Espresso, 8.8-Ounce Brick ( Multi-Pack)', 5.0), ('Lavazza 2440 Gran Filtro Dark Italian Roast Coffee, Whole Bean, 2.2 lb. Bag', 5.0)]
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeGround Coffee , WORST REVIEWS:  [('Lavazza Crema e Gusto Ground Coffee, Italian Espresso, 8.8-Ounce Brick ( Multi-Pack)', 5.0)]
#
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesToy RC Vehicles & BatteriesToy RC Vehicles , BEST REVIEWS:  [('Chicco Safari Tracker, Pink', 5.0), ('Chicco Toys Ducati 1198 Rc', 4.376237623762377), ('Chicco Radio Control Jeep (Blue)', 3.6666666666666665)]
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesToy RC Vehicles & BatteriesToy RC Vehicles , WORST REVIEWS:  [('Chicco Safari Tracker, Pink', 5.0), ('Chicco Toys Ducati 1198 Rc', 4.376237623762377), ('Chicco Radio Control Jeep (Blue)', 3.6666666666666665)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersSingle-Serve Brewers , BEST REVIEWS:  [("De'Longhi EDG605B Dolce Gusto Circolo Flow Stop Coffee Machine", 4.75), ("De'Longhi America EN750MB Nespresso Lattissima Pro Machine", 4.583333333333333), ('DeLonghi Nescafe Dolce Gusto Piccolo Plus Coffeemaker, Produces Gourmet Coffees, Lattes, Cappuccinos, Iced Drinks and more', 3.733756528042456)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee MakersSingle-Serve Brewers , WORST REVIEWS:  [("De'Longhi America EN750MB Nespresso Lattissima Pro Machine", 4.583333333333333), ('DeLonghi Nescafe Dolce Gusto Piccolo Plus Coffeemaker, Produces Gourmet Coffees, Lattes, Cappuccinos, Iced Drinks and more', 3.733756528042456), ('Gaggia for Illy Espresso Machine', 3.6393953824175487)]
#
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysActivity Centers , BEST REVIEWS:  [('Chicco Toys Smart Driver (Spanish / English)', 4.545454545454545), ('Chicco Toys Talking Farm', 4.457252960391997), ('Chicco Musical Roller', 3.444444444444445)]
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysActivity Centers , WORST REVIEWS:  [('Chicco Toys Smart Driver (Spanish / English)', 4.545454545454545), ('Chicco Toys Talking Farm', 4.457252960391997)]
#
# CATEGORY:  Toys & GamesBaby & Toddler ToysCrib Toys & Attachments , BEST REVIEWS:  [('Chicco Goodnight Stars Projector, Pink', 4.056876938986556), ('Chicco Goodnight Stars Projector, Blue', 2.5)]
# CATEGORY:  Toys & GamesBaby & Toddler ToysCrib Toys & Attachments , WORST REVIEWS:  [('Chicco Goodnight Stars Projector, Pink', 4.056876938986556)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine Accessories , BEST REVIEWS:  [('Lavazza Top Class Whole Bean Espresso, 2.2-Pound Bag', 5.000000000000001), ('Lavazza Dek Decaf Whole Bean Espresso, 1.1-Pound Bag', 5.0), ('Delonghi 5532103100 Gold Filter', 5.0)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine Accessories , WORST REVIEWS:  [('Delonghi 5332113800 Lower Tube', 4.0), ('Delonghi KW685159 Coffeemaker Water Filter 2 Pack', 3.0), ('Delonghi 5513214241 Activated Carbon Filter 1 Pack', 3.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesContact Grills , BEST REVIEWS:  [("De'Longhi BGR50 Reversible Grill/Griddle", 4.0), ('DeLonghi BQ100 Indoor Grill and Smokeless Broiler', 3.252053451023661)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesContact Grills , WORST REVIEWS:  [("De'Longhi BGR50 Reversible Grill/Griddle", 4.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machine & Coffeemaker Combos , BEST REVIEWS:  [('Delonghi EMK6 Alicia Electric Moka Espresso Coffee Maker', 4.103899273992732), ('DeLonghi ESAM6620 Gran Dama Super Automatic Beverage Center with Automatic Cappuccino', 3.790697674418605), ('DeLonghi ECAM22110SB Compact Automatic Cappuccino, Latte and Espresso Machine', 3.6264885801944606)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso Machine & Coffeemaker Combos , WORST REVIEWS:  [('Delonghi BCO264B Cafe Nero Combo Coffee and Espresso Maker', 2.4366574511882546), ('Gaggia 12500 Baby Twin Espresso Machine with Dual Heating System, Stainless Steel', 2.1373740604509837), ('DeLonghi BCO120T Combination Coffee/Espresso Machine', 2.0820611735257137)]
#
# CATEGORY:  Clothing, Shoes & JewelryNew Arrivals , BEST REVIEWS:  [("Panerai Men's M00329 Steel Luminor 1950 GMT Black Dial Watch", 5.0), ("Panerai Men's M00244 Luminor GMT Watch", 5.0), ("Panerai Men's PAM00297 Luminor GMT Black Dial Watch", 5.0)]
# CATEGORY:  Clothing, Shoes & JewelryNew Arrivals , WORST REVIEWS:  [("Panerai Men's PAM00297 Luminor GMT Black Dial Watch", 5.0), ("Panerai Men's M00311 Luminor 1950 8 Days Chrono Monopulsante GMT Titani Chronograph Watch", 4.0), ("Panerai Men's PAM00320 Luminor 1950 3-Days Automatic GMT Black Dial Watch", 1.3583833793215385)]
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & PartsRadio Transmitters , BEST REVIEWS:  [('Tactic TTX240 2.4Ghz 2CH TX RX Pistol', 5.0), ('Tactic TTX404 2.4Ghz 4CH TX RX System', 5.0), ('Tactic TTX650 2.4GHz 6CH TX Transmitter', 5.0)]
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & PartsRadio Transmitters , WORST REVIEWS:  [('Tactic TTX240 2.4Ghz 2CH TX RX Pistol', 5.0), ('Tactic TTX404 2.4Ghz 4CH TX RX System', 5.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine Replacement Parts , BEST REVIEWS:  [('Gaggia Brew Group Maintenance Kit', 4.500000000000001), ('Rancilio HSD-BS50 Base for Rancilio Silvia Espresso Machine/Rocky Grinder', 4.333333333333333), ('Double Filter Basket for Rancilio Silvia', 4.0)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine Replacement Parts , WORST REVIEWS:  [('Gaggia Brew Group Maintenance Kit', 4.500000000000001), ('Rancilio HSD-BS50 Base for Rancilio Silvia Espresso Machine/Rocky Grinder', 4.333333333333333)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesElectric Kettles , BEST REVIEWS:  [('DeLonghi Kmix 54-Ounce Kettle, Red', 3.8799141814177367), ('DeLonghi Kmix 54-Ounce Kettle, Yellow', 3.8799141814177367), ('DeLonghi Kmix 54-Ounce Kettle, Green', 3.8799141814177367)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesElectric Kettles , WORST REVIEWS:  [('DeLonghi Kmix 54-Ounce Kettle, Green', 3.8799141814177367), ('DeLonghi Kmix 54-Ounce Kettle, Magenta', 3.8799141814177367), ('DeLonghi DK350 Stainless-Steel 60-Ounce Cordless Water Kettle', 3.6891191709844557)]
#
# CATEGORY:  Home & KitchenKitchen & DiningKitchen Utensils & GadgetsTool & Gadget Sets , BEST REVIEWS:  [('DeLonghi Stainless Steel Burr Coffee Grinder with Grind Selector and Quantity Control', 3.951212264092234), ("De'Longhi CTO2003WCTO2003W 2-Slice Toaster", 2.0)]
# CATEGORY:  Home & KitchenKitchen & DiningKitchen Utensils & GadgetsTool & Gadget Sets , WORST REVIEWS:  [('DeLonghi Stainless Steel Burr Coffee Grinder with Grind Selector and Quantity Control', 3.951212264092234)]
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC VehiclesRC AircraftRC Airplanes , BEST REVIEWS:  [('Tactic TTX403 2.4GHz SLT 4-Ch Mini Transmitter', 5.0)]
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC VehiclesRC AircraftRC Airplanes , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesBaby & Toddler ToysRattles , BEST REVIEWS:  []
# CATEGORY:  Toys & GamesBaby & Toddler ToysRattles , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesElectric Skillets , BEST REVIEWS:  [("De'Longhi BG45 Electric Skillet", 4.6923076923076925), ('Delonghi BG24 Perfecto Indoor Grill', 4.304248265075604)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesElectric Skillets , WORST REVIEWS:  [("De'Longhi BG45 Electric Skillet", 4.6923076923076925)]
#
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesPlay Vehicles , BEST REVIEWS:  [('Peg Perego - 6 Volt Battery Charger (MECB0037)', 4.384615384615385), ('Chicco Turbo Touch Ducati White', 3.0)]
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesPlay Vehicles , WORST REVIEWS:  [('Peg Perego - 6 Volt Battery Charger (MECB0037)', 4.384615384615385)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersToasters , BEST REVIEWS:  [("De'Longhi CTO2003R 2-Slice Toaster", 5.0), ('DeLonghi Kmix 2-Slice Toaster, Orange', 3.280736486553219), ('DeLonghi Kmix 2-Slice Toaster, Green', 3.280736486553219)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersToasters , WORST REVIEWS:  [('DeLonghi Kmix 2-Slice Toaster, Red', 3.280736486553219), ('DeLonghi Kmix 2-Slice Toaster, White', 3.280736486553219), ('DeLonghi Kmix 2-Slice Toaster, Black', 3.280736486553219)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBlendersCountertop Blenders , BEST REVIEWS:  [('DeLonghi DFP950 Die-cast 3-in-1 Food Processor,Blender, Scale', 2.8397212543554007), ('DeLonghi DBL650 Stainless-Steel Blender with 54-Ounce Jar', 2.0)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBlendersCountertop Blenders , WORST REVIEWS:  [('DeLonghi DFP950 Die-cast 3-in-1 Food Processor,Blender, Scale', 2.8397212543554007)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine Accessories , BEST REVIEWS:  [('Gaggia 9001 Base Cafe, Black', 5.0), ("De'Longhi EC155 15 BAR Pump Espresso and Cappuccino Maker", 3.784561539900335), ('Delonghi 7332126700&nbsp;2 Cup FIlter Holder', 3.3333333333333335)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesEspresso Machine Accessories , WORST REVIEWS:  [('Gaggia 9001 Base Cafe, Black', 5.0), ("De'Longhi EC155 15 BAR Pump Espresso and Cappuccino Maker", 3.784561539900335)]
#
# CATEGORY:  Sports & OutdoorsOutdoor GearCamping & HikingKnives & ToolsFolding Knives , BEST REVIEWS:  [('Lion Steel Knives TSR1AGS Molletta Linerlock Knife with Grooved Green Aluminum Handles &amp; Matte Finish Pocket Clip', 4.0)]
# CATEGORY:  Sports & OutdoorsOutdoor GearCamping & HikingKnives & ToolsFolding Knives , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesSpecialty AppliancesSandwich Makers & Panini Presses , BEST REVIEWS:  [("De'Longhi CGH800 Contact Grill and Panini Press", 4.381544977941059)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesSpecialty AppliancesSandwich Makers & Panini Presses , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersConvection Ovens , BEST REVIEWS:  [('DeLONGHI - Convection Oven w/Rotisserie, 12.5-Liter, 0.5 cu. ft., Black', 2.0)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesOvens & ToastersConvection Ovens , WORST REVIEWS:  []
#
# CATEGORY:  Clothing, Shoes & JewelryWomen , BEST REVIEWS:  [('Brera Orologi - SuperSportivo - BRSSC4903', 5.0)]
# CATEGORY:  Clothing, Shoes & JewelryWomen , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityDehumidifiers & Accessories , BEST REVIEWS:  [('DeLonghi DD45 PE Dehumidifier with Pump', 5.0), ('DeLonghi DD70PE Dehumidifier', 3.888111888111888), ('DeLonghi DD50P 50 Pt. Energy Star Dehumidifier with Patented Pump', 2.973491853078422)]
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityDehumidifiers & Accessories , WORST REVIEWS:  [('DeLonghi DD45 PE Dehumidifier with Pump', 5.0), ('DeLonghi DD70PE Dehumidifier', 3.888111888111888), ('DeLonghi DD50P 50 Pt. Energy Star Dehumidifier with Patented Pump', 2.973491853078422)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesDeep Fryers , BEST REVIEWS:  [('Delonghi Cool Touch Roto Deep Fryer 2.2 Lb Capacity D895-UX.BK', 5.0), ('DeLonghi D34528DZ Dual Zone Deep Fryer', 4.483296213808463), ('DeLonghi D24527DZ Dual Zone 3-Pound-Capacity Deep Fryer', 4.014209160967033)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesDeep Fryers , WORST REVIEWS:  [('DeLonghi D24527DZ Dual Zone 3-Pound-Capacity Deep Fryer', 4.014209160967033), ('DeLonghi D677UX 2-1/5-Pound-Capacity Deep Fryer', 3.916275129014865), ('DeLonghi D14522DZ Dual Zone 4-Liter Deep Fryer', 3.7376303587095645)]
#
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualitySpace Heaters & Accessories , BEST REVIEWS:  [('DeLonghi TCH8093ER Ceramic Heater', 3.3333333333333335), ('DeLonghi DCH7093ER Ceramic Heater', 3.0)]
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualitySpace Heaters & Accessories , WORST REVIEWS:  [('DeLonghi TCH8093ER Ceramic Heater', 3.3333333333333335)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesMilk Frothers , BEST REVIEWS:  [('Gaggia 0077 Milk Island 0.4-Liter, Black', 2.6666666666666674)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesMilk Frothers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Grinders , BEST REVIEWS:  [('Rancilio HSD-ROC-SD Rocky Coffee Grinder', 4.457891820543983), ('Rancilio HSD-ROC-SS Rocky Coffee Grinder', 4.334553912538895), ('Rancilio Rocky Grinder Burrs', 4.0)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Grinders , WORST REVIEWS:  [('Gaggia 8002 MDF Burr Grinder with Doser, Black', 3.970073307173138), ('DeLonghi KG79 Electric 12-Cup Burr Grinder, Black', 3.7733283453424633), ('Gaggia MDF Coffee Grinder with Doser', 3.4999999999999996)]
#
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesVehicle Playsets , BEST REVIEWS:  []
# CATEGORY:  Toys & GamesToy Remote Control & Play VehiclesVehicle Playsets , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & Dining , BEST REVIEWS:  [('DeLonghi FK8 Deep Fryer Replacement Filters for model  D895', 4.663265306122448)]
# CATEGORY:  Home & KitchenKitchen & Dining , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesBeverage Warmers , BEST REVIEWS:  [('DeLonghi ECAM23210B Compact Magnifica S Beverage Center, Black', 4.248016706929827)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesCoffee, Tea & Espresso AppliancesBeverage Warmers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesSmall Appliance Sets , BEST REVIEWS:  [('DeLonghi Red Lattissima Plus Nespresso Capsule System', 4.262245681749848), ('DeLonghi Compact Automatic Cappuccino, Latte and Espresso Machine, Silver', 4.151515151515151), ("De'Longhi EC860 Espresso Maker, 1, Stainless Steel", 3.740175381617409)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesSmall Appliance Sets , WORST REVIEWS:  [('DeLonghi Compact Automatic Cappuccino, Latte and Espresso Machine, Silver', 4.151515151515151), ("De'Longhi EC860 Espresso Maker, 1, Stainless Steel", 3.740175381617409), ('DeLonghi BCO320T Combination Espresso and Drip Coffee- Black', 3.117541789798763)]
#
# CATEGORY:  Toys & Games , BEST REVIEWS:  [('Chicco Turbo Touch Wild No.44', 4.0), ('Chicco Radio Control Jeep (Orange)', 2.5)]
# CATEGORY:  Toys & Games , WORST REVIEWS:  [('Chicco Turbo Touch Wild No.44', 4.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffeemaker Pots , BEST REVIEWS:  [('Delonghi 7313283649 Glass Coffee Carafe', 5.0), ('Saeco Intenza Replacement Water Filter, Box of 6', 4.8), ('DeLonghi 12-cup Glass Carafe', 4.333333333333333)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffeemaker Pots , WORST REVIEWS:  [('Delonghi 7313283649 Glass Coffee Carafe', 5.0), ('Saeco Intenza Replacement Water Filter, Box of 6', 4.8), ('DeLonghi 12-cup Glass Carafe', 4.333333333333333)]
#
# CATEGORY:  Baby ProductsGearWalkers , BEST REVIEWS:  [('Chicco Baby Activity Walker', 4.352941176470588), ('Chicco Baby Jogging', 3.9481089819301793)]
# CATEGORY:  Baby ProductsGearWalkers , WORST REVIEWS:  [('Chicco Baby Activity Walker', 4.352941176470588)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffee FiltersReusable Filters , BEST REVIEWS:  [('Delonghi 7332173800 2 Cup Filter Assembly', 4.4)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffee FiltersReusable Filters , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesJuicersCitrus Juicers , BEST REVIEWS:  [('DeLonghi KS500 34-Ounce-Capacity Electric Citrus Juicer', 2.0864764682779686)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesJuicersCitrus Juicers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesIce Cream Machines , BEST REVIEWS:  [('DeLonghi GM6000 Gelato Maker with Self-Refrigerating Compressor', 4.009533042605024)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesIce Cream Machines , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningWater Coolers & FiltersPitcher Water Filters , BEST REVIEWS:  [('Saeco 21001120 Intenza Water Filter', 5.0), ('Saeco APWF Aqua Prima Water Filter', 5.0)]
# CATEGORY:  Home & KitchenKitchen & DiningWater Coolers & FiltersPitcher Water Filters , WORST REVIEWS:  [('Saeco 21001120 Intenza Water Filter', 5.0)]
#
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingCups, Mugs & SaucersCoffee Cups & Mugs , BEST REVIEWS:  [('Delonghi Descaler for Coffee Maker (2 x 100ml)', 2.0)]
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingCups, Mugs & SaucersCoffee Cups & Mugs , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesSports & Outdoor PlayPlayhouses , BEST REVIEWS:  [('Chicco Toys 1 Two 3 Playhouse', 4.857142857142858)]
# CATEGORY:  Toys & GamesSports & Outdoor PlayPlayhouses , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesJuicersCentrifugal Juicers , BEST REVIEWS:  [('DeLonghi DJE950 Die-cast Juice Extractor', 4.3482758620689665)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesJuicersCentrifugal Juicers , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesBaby & Toddler Toys , BEST REVIEWS:  [('Chicco Talking Carpenter', 4.5)]
# CATEGORY:  Toys & GamesBaby & Toddler Toys , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesFood Processors , BEST REVIEWS:  [('DeLonghi 9-Cup Capacity Food Processor with Integrated Blender', 4.125954862963109)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesFood Processors , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir PurifiersHEPA Air Purifiers , BEST REVIEWS:  []
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir PurifiersHEPA Air Purifiers , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesStuffed Animals & PlushAnimals & Figures , BEST REVIEWS:  [('Chicco Musical Walking Turtles', 3.473684210526316), ('Chicco Count-with-Me Teddy Bear', 3.3333333333333335)]
# CATEGORY:  Toys & GamesStuffed Animals & PlushAnimals & Figures , WORST REVIEWS:  [('Chicco Musical Walking Turtles', 3.473684210526316)]
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSteam Espresso Machines , BEST REVIEWS:  [('DeLonghi EC5 Steam-Driven 4-Cup Espresso and Coffee Maker, Black', 2.8816138068772923), ('Gaggia 102533 Espresso-Dose Semi-Automatic Espresso Machine, Warm Silver', 1.9774011299435028)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoEspresso MachinesSteam Espresso Machines , WORST REVIEWS:  [('DeLonghi EC5 Steam-Driven 4-Cup Espresso and Coffee Maker, Black', 2.8816138068772923)]
#
# CATEGORY:  Grocery & Gourmet FoodCandy & ChocolateBars , BEST REVIEWS:  []
# CATEGORY:  Grocery & Gourmet FoodCandy & ChocolateBars , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBlendersHand Blenders , BEST REVIEWS:  [('DeLonghi DHB718 380-Watt Tri-Blade 2-Speed Handblender with Whisk', 3.759136823558592), ('DeLonghi DHB716 380-Watt Tri-Blade 2-Speed Handblender', 3.6363234013652983), ('DeLonghi Professional Triblade Hand Blender with Variable Speeds', 1.0)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBlendersHand Blenders , WORST REVIEWS:  [('DeLonghi DHB718 380-Watt Tri-Blade 2-Speed Handblender with Whisk', 3.759136823558592), ('DeLonghi DHB716 380-Watt Tri-Blade 2-Speed Handblender', 3.6363234013652983)]
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle Parts , BEST REVIEWS:  [('Tactic 4 Cell AA Battery Holder with Fut J Connector', 5.0)]
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle Parts , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffeemaker Pot Lids , BEST REVIEWS:  [('DeLonghi Accessory Kit for Esclusivo Alicia Electric Espresso Maker', 4.851851851851852)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffeemaker Pot Lids , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Makers , BEST REVIEWS:  [('DeLonghi Nescafe Dolce Gusto Circolo Coffeemaker, Black', 3.844073264760377), ('Gaggia Mavea Intenza Water Filter 21001711', 1.0)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee Makers , WORST REVIEWS:  [('DeLonghi Nescafe Dolce Gusto Circolo Coffeemaker, Black', 3.844073264760377)]
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffee Filters , BEST REVIEWS:  [('Gaggia Pressurized Espresso Filter Basket', 3.6666666666666665)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine AccessoriesCoffee Filters , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesDolls & AccessoriesDoll AccessoriesStrollers , BEST REVIEWS:  [('Doll Stroller', 4.652770785202058)]
# CATEGORY:  Toys & GamesDolls & AccessoriesDoll AccessoriesStrollers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenIrons & SteamersIronsAutomatic Turnoff Irons , BEST REVIEWS:  [('DeLonghi VVX1470XGA Ironing Steam Station', 4.252912787013114), ('DeLonghi 1750-Watt Steam Iron with Ceramic and Stainless Steel Soleplate', 2.923245318604338)]
# CATEGORY:  Home & KitchenIrons & SteamersIronsAutomatic Turnoff Irons , WORST REVIEWS:  [('DeLonghi VVX1470XGA Ironing Steam Station', 4.252912787013114)]
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & Parts , BEST REVIEWS:  [('Tactic TTX600 2.4GHZ 6CH TX RX Radio System', 4.571428571428571)]
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsRadios & Parts , WORST REVIEWS:  []
#
# CATEGORY:  Tools & Home ImprovementBuilding SuppliesHeating & CoolingHeaters & Accessories , BEST REVIEWS:  [('DeLonghi DCH1030 Safeheat 1500W Basic Ceramic Heater - Gray/Black', 3.842148360314913)]
# CATEGORY:  Tools & Home ImprovementBuilding SuppliesHeating & CoolingHeaters & Accessories , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir PurifiersCharcoal Air Purifiers , BEST REVIEWS:  []
# CATEGORY:  Home & KitchenHeating, Cooling & Air QualityAir PurifiersCharcoal Air Purifiers , WORST REVIEWS:  []
#
# CATEGORY:  Clothing, Shoes & JewelryMenWatchesWrist Watches , BEST REVIEWS:  []
# CATEGORY:  Clothing, Shoes & JewelryMenWatchesWrist Watches , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesElectronics for KidsCameras & Camcorders , BEST REVIEWS:  [('Chicco Smile Camera', 1.4055749441910215)]
# CATEGORY:  Toys & GamesElectronics for KidsCameras & Camcorders , WORST REVIEWS:  []
#
# CATEGORY:  BeautyHair CareConditioners , BEST REVIEWS:  []
# CATEGORY:  BeautyHair CareConditioners , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysSorting & Stacking , BEST REVIEWS:  [('Chicco Shapes and Sounds Tambourine', 3.8571428571428568)]
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysSorting & Stacking , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCookwareCookware Sets , BEST REVIEWS:  []
# CATEGORY:  Home & KitchenKitchen & DiningCookwareCookware Sets , WORST REVIEWS:  []
#
# CATEGORY:  Clothing, Shoes & JewelryNovelty, Costumes & MoreJewelry Accessories , BEST REVIEWS:  []
# CATEGORY:  Clothing, Shoes & JewelryNovelty, Costumes & MoreJewelry Accessories , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsBatteries & ChargersBattery Chargers , BEST REVIEWS:  []
# CATEGORY:  Toys & GamesHobbiesRC Vehicles & PartsRC Vehicle PartsBatteries & ChargersBattery Chargers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCookwareTeakettles , BEST REVIEWS:  [("De'Longhi KBO1401R Electric Kettle", 5.0)]
# CATEGORY:  Home & KitchenKitchen & DiningCookwareTeakettles , WORST REVIEWS:  []
#
# CATEGORY:  Sports & OutdoorsFan ShopToys & Game RoomToy Vehicles , BEST REVIEWS:  [('Chicco Toys Rodeo Ride On', 4.5)]
# CATEGORY:  Sports & OutdoorsFan ShopToys & Game RoomToy Vehicles , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & Espresso , BEST REVIEWS:  [('Saeco 00347 Aroma Espresso Machine, Black', 3.458947196796849), ('Philips Saeco RI9376/04 Aroma Espresso Machine, Stainless Steel', 3.458947196796849)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & Espresso , WORST REVIEWS:  [('Saeco 00347 Aroma Espresso Machine, Black', 3.458947196796849)]
#
# CATEGORY:  Grocery & Gourmet FoodBeveragesTeaTea Samplers , BEST REVIEWS:  []
# CATEGORY:  Grocery & Gourmet FoodBeveragesTeaTea Samplers , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine Replacement Parts , BEST REVIEWS:  []
# CATEGORY:  Home & KitchenKitchen & DiningSmall Appliance Parts & AccessoriesCoffee & Espresso Machine Parts & AccessoriesCoffee Machine Replacement Parts , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee GrindersElectric Blade Grinders , BEST REVIEWS:  [('DeLonghi KG40 Electric Coffee-Bean Grinder with Stainless-Steel Blade', 1.2445225858804436)]
# CATEGORY:  Home & KitchenKitchen & DiningCoffee, Tea & EspressoCoffee GrindersElectric Blade Grinders , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesBaby & Toddler ToysBath Toys , BEST REVIEWS:  [('Chicco Bubble Island', 3.0)]
# CATEGORY:  Toys & GamesBaby & Toddler ToysBath Toys , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingGlassware & DrinkwareMixed Drinkware Sets , BEST REVIEWS:  []
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingGlassware & DrinkwareMixed Drinkware Sets , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBread Machines , BEST REVIEWS:  [('DeLonghi Bread Maker', 4.142038875746073)]
# CATEGORY:  Home & KitchenKitchen & DiningSmall AppliancesBread Machines , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingCups, Mugs & SaucersCup & Saucer Sets , BEST REVIEWS:  [('Lavazza - 2oz Porcelain Espresso Cup with Saucer (Set of 12 Cups and Saucers)', 4.0)]
# CATEGORY:  Home & KitchenKitchen & DiningDining & EntertainingCups, Mugs & SaucersCup & Saucer Sets , WORST REVIEWS:  []
#
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysShapes & Colors , BEST REVIEWS:  [('Chicco Animal Cottage', 2.573770491803279)]
# CATEGORY:  Toys & GamesLearning & EducationEarly Development ToysShapes & Colors , WORST REVIEWS:  []
#
# CATEGORY:  Home & KitchenKitchen & DiningCookwareAll Pans , BEST REVIEWS:  [('Delonghi Model OS-03 Cook and Serve 5-1/2-Quart Pan with Lid', 1.0)]
# CATEGORY:  Home & KitchenKitchen & DiningCookwareAll Pans , WORST REVIEWS:  []
#
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Capsules , BEST REVIEWS:  []
# CATEGORY:  Grocery & Gourmet FoodBeveragesCoffeeSingle-Serve Capsules , WORST REVIEWS:  []

# %%
mean_ratings(data_new_categories)
print("\n\n")
popular_products(data_new_categories)
print("\n\n")
#popular_brands(data_new_categories)
# Out:
# electronic_and_games, number of votes: 57, mean: 3.7222222222222223
# food, number of votes: 13478, mean: 4.19842953710378
# personal_care, number of votes: 1, mean: 0
# kitchen_tools, number of votes: 24, mean: 4.523870146403564
# fashion, number of votes: 22, mean: 3.64219723825575
#
#
#
# CATEGORY:  food , BEST REVIEWS:  [('Ferrero Yogurette 24 pieces', 5.0), ('Parmalat 2% Reduced Fat Milk 1 Qt (Pack of 6)', 5.0), ('Tic Tac Big Pack Cherry Passion (Pack of 12)', 5.0)]
# CATEGORY:  food , WORST REVIEWS:  [('Peg Perego Tatamia Kit, Verde', 1.0), ('Nutella 6.6lb Tub', 1.0), ('Lavazza Espresso Delicato for Keurig Rivo System', 1.0)]
#
# CATEGORY:  fashion , BEST REVIEWS:  [("Panerai Luminor 1950 10 Days Men's Automatic - PAM00270", 5.0), ("Panerai Men's M00329 Steel Luminor 1950 GMT Black Dial Watch", 5.0), ('Brera Orologi - SuperSportivo - BRSSC4903', 5.0)]
# CATEGORY:  fashion , WORST REVIEWS:  [("Panerai Men's M00244 Luminor GMT Watch", 5.0), ("Panerai Men's M00311 Luminor 1950 8 Days Chrono Monopulsante GMT Titani Chronograph Watch", 4.0), ("Panerai Men's PAM00320 Luminor 1950 3-Days Automatic GMT Black Dial Watch", 1.3583833793215385)]
#
# CATEGORY:  electronic_and_games , BEST REVIEWS:  [('Peg Perego - 6 Volt Battery Charger (MECB0037)', 4.384615384615385), ('Chicco Turbo Touch Wild No.44', 4.0), ('Chicco Turbo Touch Ducati White', 3.0)]
# CATEGORY:  electronic_and_games , WORST REVIEWS:  [('Peg Perego - 6 Volt Battery Charger (MECB0037)', 4.384615384615385), ('Chicco Turbo Touch Wild No.44', 4.0), ('Chicco Turbo Touch Ducati White', 3.0)]
#
# CATEGORY:  kitchen_tools , BEST REVIEWS:  [('DeLonghi FK8 Deep Fryer Replacement Filters for model  D895', 4.663265306122448), ('Lion Steel Knives TSR1AGS Molletta Linerlock Knife with Grooved Green Aluminum Handles &amp; Matte Finish Pocket Clip', 4.0), ('Delonghi Descaler for Coffee Maker (2 x 100ml)', 2.0)]
# CATEGORY:  kitchen_tools , WORST REVIEWS:  [('DeLonghi FK8 Deep Fryer Replacement Filters for model  D895', 4.663265306122448), ('Lion Steel Knives TSR1AGS Molletta Linerlock Knife with Grooved Green Aluminum Handles &amp; Matte Finish Pocket Clip', 4.0)]
#
# CATEGORY:  personal_care , BEST REVIEWS:  []
# CATEGORY:  personal_care , WORST REVIEWS:  []

# %%
data_new_categories["categories"].drop_duplicates()
# Out:
# 0                        food
# 564                   fashion
# 4729     electronic_and_games
# 5382            kitchen_tools
# 20051           personal_care
# Name: categories, dtype: object
